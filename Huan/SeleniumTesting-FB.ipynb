# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
from selenium import webdriver
import os
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities


driver = webdriver.Chrome(r'C:\Users\Admin\Desktop\chromedriver.exe')
url='http://www.fanatics.com/search/red%20shoes'
driver.get(url)
#driver.set_page_load_timeout(300)
driver.implicitly_wait(60)
alert = driver.switch_to_alert()
alert.dismiss
handle=driver.window_handles
print ('sadsadas')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# <ipython-input-5-22f09a58e029> in <module>
#       9 #driver.set_page_load_timeout(300)
#      10 driver.implicitly_wait(60)
# ---> 11 alert = driver.switch_to_alert()
#      12 alert.dismiss
#      13 handle=driver.window_handles
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in switch_to_alert(self)
#     801         warnings.warn("use driver.switch_to.alert instead",
#     802                       DeprecationWarning, stacklevel=2)
# --> 803         return self._switch_to.alert
#     804
#     805     # Navigation
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py in alert(self)
#      53         """
#      54         alert = Alert(self._driver)
# ---> 55         alert.text
#      56         return alert
#      57
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\alert.py in text(self)
#      67             return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#      68         else:
# ---> 69             return self.driver.execute(Command.GET_ALERT_TEXT)["value"]
#      70
#      71     def dismiss(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)

# %%
tech_divs = soup.find_all('div', attrs={'class':'_4-u2 mbm _4mrt _5jmm _5pat _5v3q _7cqq _4-u8'})

# %%
from urllib.parse import urljoin
from collections import namedtuple

TechBasic = namedtuple('TechBasic', 'url, content, date, user')

def data_extraction(post):
    url_base = 'https://www.facebook.com'
    if len(post.select('p')) != 0:
        post_content =  post.select('p')[0].text
    else: 
        post_content = 0
    return TechBasic(url=urljoin(url_base, post.select('a')[0]['href']), content= post_content, date = post.select('abbr')[0]['title'], user = post.select('img')[0]['aria-label'])

# %%
results = []
for i in range(len(tech_divs)):
    results.append(data_extraction(tech_divs[i]))

# %%
urls_list = [results[i].url for i in range(len(tech_divs))]
content_list = [results[i].content for i in range(len(tech_divs))]
date_list = [results[i].date for i in range(len(tech_divs))]
user_list = [results[i].user for i in range(len(tech_divs))]

# %%
data_dict = {'urls':urls_list, 'content':content_list, 'date':date_list, 'user':user_list}

# %%
data = pd.DataFrame(data_dict)

# %%
data.to_csv('test.csv')

# %%
data
# Out:
#                                                    urls  \
# 0     https://www.facebook.com/groups/87066574971885...
# 1     https://www.facebook.com/groups/87066574971885...
# 2     https://www.facebook.com/groups/87066574971885...
# 3     https://www.facebook.com/groups/87066574971885...
# 4     https://www.facebook.com/groups/87066574971885...
# 5     https://www.facebook.com/groups/87066574971885...
# 6     https://www.facebook.com/groups/87066574971885...
# 7     https://www.facebook.com/groups/87066574971885...
# 8     https://www.facebook.com/groups/87066574971885...
# 9     https://www.facebook.com/groups/87066574971885...
# 10    https://www.facebook.com/groups/87066574971885...
# 11    https://www.facebook.com/groups/87066574971885...
# 6     Bên mình cần tuyển #Tester và #Data Management...  23:35, 02/01/2019
# 7     SAIGON CO.OP và cơ hội việc làm đầu năm mới. ♦...  05:38, 02/01/2019
# 8     Talent Wins Trân Trọng Giới Thiệu: HR TECH DAY...  22:12, 28/12/2018
# 9     Chia Sẻ Khóa Học Blockchain For Business 2018:...  20:23, 02/01/2019
# 10    #GHTK #Bigdata #data #NLP #machinelearning 🎉Gi...  20:22, 03/12/2018
# 11    Xin chào, hiện tại mình đang có nhu cầu muốn l...  20:44, 01/01/2019
# 12    Lemmatization vs Stemming. Where does this top...  17:45, 02/01/2019
# 13    Google Duplex,Google Assistant, Amazon Alexa, ...  17:41, 02/01/2019
# 14    Hi All, If you are really keen on learning Mac...  09:47, 02/01/2019
# 15    Lemmatization vs Stemming. Where does this top...  09:46, 02/01/2019
# 16    Using Bigdata and Machine Learning to prevent ...  08:03, 02/01/2019
# 17    Tôi là Biển, Giám đốc kỹ thuật nền tảng của DE...  02:18, 02/01/2019
# 18    The best way to start a new year is by impleme...  07:07, 02/01/2019
# 19    🍀 hiện tại bên TT MÌNH đang tổ chức lớp học ti...  06:54, 02/01/2019
# 20    Chia Sẻ Khóa Học Phân Tích Dữ Liệu Lớn Với Apa...  23:54, 01/01/2019
# 21    Hiện mình đang là Researcher, muốn tìm một vài...  18:56, 01/01/2019
# 22    Viện Nghiên cứu ứng dụng Công nghệ CMC thuộc T...  02:02, 02/01/2019
# 23    [HCM] IT back end, front end, scrum master, da...  20:01, 27/12/2018
# 24    có bác nào chạy Z-socre cho em xin cái số Z'=x...  19:35, 01/01/2019
# 25    Chia Sẻ Khóa Học Thống Kê Cho Khoa Học Dữ Liệu...  18:10, 28/12/2018
# 26                                                    0  22:17, 01/01/2019
# 27    Nhanh tay đăng ký buổi review về cấu trúc dữ l...  22:04, 01/01/2019
# 28           [Blockchain for Business] [Bigdata vs IoT]  22:24, 31/12/2018
# 29    Nhóm chuyên về jobs AI & Data Science: #DevJob...  21:33, 13/12/2018
# ...                                                 ...                ...
# 1373                                                  0  08:18, 30/07/2016
# 1374  Trong buổi meetup vừa qua, anh Kiên có nhắc đế...  06:41, 30/07/2016
# 1375                                                  0  05:36, 28/07/2016
# 1376  Hiện tại mình đang cần lập team phát tri...  17:19, 20/07/2016
# 1377  Hi everyone,  I would like to invite all of yo...  04:37, 05/07/2016
# 1378                                                  0  23:16, 26/06/2016
# 1379            First offline event at Tinypulse office  23:22, 23/06/2016
# 1380  Dành cho những ai muốn học Spark. Khoá học đầu...  23:53, 16/06/2016
# 1381  http://www.mastersindatascience.org/careers/da...  20:16, 03/06/2016
# 1382  Zalora đang tuyển vài vị trí Data Engineer cho...  01:28, 21/05/2016
# 1383  alo alo, tình hình offline trong tháng 6 như t...  01:24, 30/05/2016
# 1384        https://www.youtube.com/watch?v=PivpCKEiQOQ  00:37, 23/05/2016
# 1385  em có add Bach Quang Bao Toan  và Nghia Nguyen...  06:53, 17/05/2016
# 1386  THAM GIA LĨNH VỰC DATA SCIENCE TỪ NHỮNG NGÀNH ...  03:25, 14/05/2016
# 1387          BÀN VỀ NHU CẦU DATA SCIENTIST Ở VIỆT NAM   03:57, 07/05/2016
# 1388  "9 Must-Have Skills to Land Top Big Data Jobs ...  01:14, 01/05/2016
# 1389                              First offline meeting  16:25, 23/04/2016
# 1390  Thông báo khẩn: Moss cafe hơi bị chật, đang tì...  00:52, 23/04/2016
# 1391  Thứ 7 tuần này nhân dịp Duy Ngan Le về VN, dự ...  02:59, 19/04/2016
# 1392  Offline gặp mặt nhóm lần đầu vào cuối tuần này...  05:33, 19/04/2016
# 1393     Hôm nào sắp xếp cafe chém gió đi Quang Hieu Vu  07:11, 11/03/2016
# 1394  Điểm danh xem có đại diện của big data nào của...  06:58, 03/03/2016
# 1395  The purpose of this group is to create a commu...  04:46, 03/03/2016
# 1396  The purpose of this group is to create a commu...  04:45, 03/03/2016
# 1397                                                  0  18:49, 01/03/2016
# 1398                                                  0  18:48, 01/03/2016
# 1399                                                  0  18:45, 01/03/2016
# 1400                                                  0  18:44, 01/03/2016
# 1401                                                  0  18:41, 01/03/2016
# 1402                                                  0  16:31, 21/11/2015
#
#                    user
# 0       Nguyen Viet Nam
# 1           Trương Việt
# 2         Bhavesh Bhatt
# 3         Phương Phương
# 4       Huynh Dat Thuan
# 5     Mai Thị Vân Huyền
# 6      Nguyễn Thu Hường
# 7              Lam Thao
# 8         Huong Thu Bui
# 9            Quốc Vương
# 10     Nguyễn Thùy Linh
# 11           Jimmy Phan
# 12           Krish Naik
# 13           Krish Naik
# 14           Krish Naik
# 15           Krish Naik
# 16      Duc Minh Nguyen
# 17           Bien Hoang
# 18        Bhavesh Bhatt
# 19        Phương Phương
# 20           Quốc Vương
# 21             Phưn Như
# 22          Trần Hà Thu
# 23      Nguyễn Linh Chi
# 24             Anh Tuan
# 25             Lâm Tuấn
# 26      Manikanta Thota
# 27         Cuong Nguyen
# 28        Tuấn Anh Phạm
# 29        Huong Thu Bui
# ...                 ...
# 1373           Thuan Le
# 1374         Trung Phan
# 1375         Phong Tran
# 1376          trần khoa
# 1377       Anh Hoang Le
# 1378         Vinh Huynh
# 1379           Thuan Le
# 1380     Hồ Viết Thuyên
# 1381       Trung Nguyễn
# 1382        Duy Ngan Le
# 1383         Vinh Huynh
# 1384       Trung Nguyễn
# 1385         Phong Tran
# 1386        Duy Ngan Le
# 1387        Duy Ngan Le
# 1388        Duy Ngan Le
# 1389      Quang Hieu Vu
# 1390           Thuan Le
# 1391           Thuan Le
# 1392      Quang Hieu Vu
# 1393           Thuan Le
# 1394           Thuan Le
# 1395      Quang Hieu Vu
# 1396      Quang Hieu Vu
# 1397        Duy Ngan Le
# 1398        Duy Ngan Le
# 1399        Duy Ngan Le
# 1400        Duy Ngan Le
# 1401        Duy Ngan Le
# 1402        Duy Ngan Le
#
# [1403 rows x 4 columns]
